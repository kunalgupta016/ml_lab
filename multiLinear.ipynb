# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn import linear_model
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Age.csv')

# %%
sns.lmplot(x='Age', y='Premium', data=data)

# %%
sns.stripplot(x='Age', y='Premium', data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Premium'>

# %%
plt.plot(data['Age'], data['Premium'])
plt.xlabel('Age')
plt.ylabel('Premium')
plt.show()

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(data[['Age']],data['Premium'])
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([1780.])

# %%
reg.intercept_
# Out:
# np.float64(-23500.0)

# %%
reg.predict([[22]])
# Out:
# c:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([15660.])

# %%
reg.predict([[55]])
# Out:
# c:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([74400.])

# %%
reg.predict([[33]])
# Out:
# c:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([35240.])
